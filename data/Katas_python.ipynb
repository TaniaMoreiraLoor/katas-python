# %%
import math
from functools import reduce

# %%
# Ejercicio 1: Contar letras en un texto
def contar_letras(texto):
    frecuencia = {}

    for letra in texto:
        if letra != " ":
            if letra in frecuencia:
                frecuencia[letra] += 1
            else:
                frecuencia[letra] = 1

    return frecuencia

# %%
resultado = contar_letras("Hola mundo")
print(resultado)
# Out:
# {'H': 1, 'o': 2, 'l': 1, 'a': 1, 'm': 1, 'u': 1, 'n': 1, 'd': 1}

# %%
# Ejercicio 2: Duplicar valores en una lista
def duplicar_valores(lista):
    return list(map(lambda numero: numero * 2, lista))

# %%
# Ejemplo de uso
numeros = [1, 2, 3, 4, 5]
resultado = duplicar_valores(numeros)

print(resultado)
# Out:
# [2, 4, 6, 8, 10]

# %%
# Ejercicio 3: Buscar palabras 
def buscar_palabras(lista_palabras, palabra_objetivo):
    resultado = []

    for palabra in lista_palabras:
        if palabra_objetivo in palabra:
            resultado.append(palabra)

    return resultado

# %%
# Ejemplo de uso
palabras = ["casa", "casita", "perro", "caserón", "gato"]

resultado = buscar_palabras(palabras, "casa")
print(resultado)
# Out:
# ['casa']

# %%
# Ejercicio 4: Calcular la diferencia entre dos listas
def calcular_diferencia(lista1, lista2):
    return list(map(lambda x, y: x - y, lista1, lista2))

# %%
# Ejemplo de uso
lista1 = [10, 20, 30]
lista2 = [1, 2, 3]

resultado = calcular_diferencia(lista1, lista2)

print(resultado)
# Out:
# [9, 18, 27]

# %%
# Ejercicio 5: Calcular nota media de un estudiante
def evaluar_notas(lista_notas, nota_aprobado=5):
    media = sum(lista_notas) / len(lista_notas)

    if media >= nota_aprobado:
        estado = "aprobado"
    else:
        estado = "suspenso"

    return (media, estado)

# %%
# Ejemplo de uso
notas = [4, 9, 6, 5]

resultado = evaluar_notas(notas)

print(resultado)
# Out:
# (6.0, 'aprobado')

# %%
# Ejercicio 6: Calcular el factorial de un número
def factorial(numero):
    if numero == 0 or numero == 1:
        return 1
    else:
        return numero * factorial(numero - 1)

# %%
# Ejemplo de uso
print(factorial(5))
# Out:
# 120

# %%
# Ejercicio 7: Convertir tuplas a strings
def tuplas_a_strings(lista_tuplas):
    return list(map(str, lista_tuplas))

# %%
# Ejemplo de uso
datos = [
    ("Tania", 25),
    ("Juan", 30),
    ("Ana", 22)
]

resultado = tuplas_a_strings(datos)

print(resultado)
# Out:
# ["('Tania', 25)", "('Juan', 30)", "('Ana', 22)"]

# %%
# Ejercicio 8: Manejo de excepciones
try:
    numero1 = float(input("Introduce el primer número: "))
    numero2 = float(input("Introduce el segundo número: "))

    resultado = numero1 / numero2

    print(f"La división es: {resultado}")
    print("La división fue exitosa.")

except ValueError:
    print("Error: Debes introducir valores numéricos.")

except ZeroDivisionError:
    print("Error: No se puede dividir entre cero.")
# Out:
# Error: Debes introducir valores numéricos.

# %%
# Ejercicio 9: Manejo de excepciones con archivos
def filtrar_mascotas(lista_mascotas):
    mascotas_prohibidas = [
        "Mapache",
        "Tigre",
        "Serpiente Pitón",
        "Cocodrilo",
        "Oso"
    ]

    return list(
        filter(
            lambda mascota: mascota not in mascotas_prohibidas,
            lista_mascotas
        )
    )

# %%
# Ejemplo de uso
mascotas = [
    "Perro",
    "Gato",
    "Mapache",
    "Conejo",
    "Oso",
    "Loro"
]

resultado = filtrar_mascotas(mascotas)

print(resultado)
# Out:
# ['Perro', 'Gato', 'Conejo', 'Loro']

# %%
# Ejercicio 10: Excepción personalizada
class ListaVaciaError(Exception):
    pass


def calcular_promedio(lista):
    if len(lista) == 0:
        raise ListaVaciaError("La lista está vacía.")

    return sum(lista) / len(lista)


try:
    numeros = [10, 20, 30, 40]

    promedio = calcular_promedio(numeros)

    print(f"El promedio es: {promedio}")

except ListaVaciaError as error:
    print(f"Error: {error}")
# Out:
# Error: La lista está vacía.

# %%
# Ejercicio 11: Validar edad con excepciones personalizadas
try:
    edad = int(input("Introduce tu edad: "))

    if edad < 0 or edad > 120:
        raise ValueError("La edad debe estar entre 0 y 120 años.")

    print(f"Tu edad es {edad} años.")

except ValueError as error:
    print(f"Error: {error}")
# Out:
# Tu edad es 31 años.

# %%
# Ejercicio 12: Longitud de palabras en una frase
def longitud_palabras(frase):
    palabras = frase.split()

    return list(map(len, palabras))

# %%
# Ejemplo de uso
resultado = longitud_palabras("Hola me llamo Tania")

print(resultado)
# Out:
# [4, 2, 5, 5]

# %%
# Ejercicio 13: Letras mayúsculas y minúsculas
def letras_mayus_minus(caracteres):
    letras_unicas = set(caracteres)

    return list(map(lambda letra: (letra.upper(), letra.lower()), letras_unicas))

# %%
# Ejemplo de uso
resultado = letras_mayus_minus("Tania")

print(resultado)
# Out:
# [('I', 'i'), ('A', 'a'), ('N', 'n'), ('T', 't')]

# %%
# Ejercicio 14: Filtrar palabras por letra
def palabras_por_letra(lista_palabras, letra):
    return list(filter(lambda palabra: palabra.startswith(letra), lista_palabras))

# %%
# Ejemplo de uso
palabras = ["casa", "perro", "camisa", "gato", "coche"]

resultado = palabras_por_letra(palabras, "c")

print(resultado)
# Out:
# ['casa', 'camisa', 'coche']

# %%
# Ejercicio 15: Sumar un número a cada elemento de una lista
sumar_tres = lambda numero: numero + 3

numeros = [1, 2, 3, 4, 5]

resultado = list(map(sumar_tres, numeros))

print(resultado)
# Out:
# [4, 5, 6, 7, 8]

# %%
# Ejercicio 16: Filtrar palabras largas
def palabras_largas(texto, n):
    palabras = texto.split()

    return list(filter(lambda palabra: len(palabra) > n, palabras))

# %%
# Ejemplo de uso
resultado = palabras_largas("Mi perro es un mastin enorme", 4)

print(resultado)
# Out:
# ['perro', 'mastin', 'enorme']

# %%
# Ejercicio 17: Convertir lista de dígitos a número
def lista_a_numero(lista_digitos):
    return reduce(lambda x, y: x * 10 + y, lista_digitos)

# %%
# Ejemplo de uso
resultado = lista_a_numero([5, 7, 2])

print(resultado)
# Out:
# 572

# %%
# Ejercicio 18: Filtrar estudiantes destacados
def estudiantes_destacados(estudiantes):
    return list(
        filter(
            lambda estudiante: estudiante["calificacion"] >= 90,
            estudiantes
        )
    )

# %%
# Ejemplo de uso
estudiantes = [
    {"nombre": "Tania", "edad": 20, "calificacion": 95},
    {"nombre": "Lucero", "edad": 22, "calificacion": 80},
    {"nombre": "Jonna", "edad": 21, "calificacion": 90},
    {"nombre": "Annel", "edad": 19, "calificacion": 85}
]

resultado = estudiantes_destacados(estudiantes)

print(resultado)
# Out:
# [{'nombre': 'Tania', 'edad': 20, 'calificacion': 95}, {'nombre': 'Jonna', 'edad': 21, 'calificacion': 90}]

# %%
# Ejercicio 19: Filtrar números impares
def filtrar_impares(lista):
    return list(filter(lambda numero: numero % 2 != 0, lista))

# %%
# Ejemplo de uso
numeros = [112, 2, 25, 139, 5, 6, 55, 8, 9]

resultado = filtrar_impares(numeros)

print(resultado)
# Out:
# [25, 139, 5, 55, 9]

# %%
# Ejercicio 20: Filtrar enteros de una lista
def filtrar_enteros(lista):
    return list(filter(lambda elemento: isinstance(elemento, int), lista))

# %%
# Ejemplo de uso
datos = [1, "hola", 5, "perro", 10, "gato", 20]

resultado = filtrar_enteros(datos)

print(resultado)
# Out:
# [1, 5, 10, 20]

# %%
# Ejercicio 21: Calcular el cubo de un número
def calcular_cubo(numero):
    cubo = lambda x: x ** 3
    return cubo(numero)

# %%
# Ejemplo de uso
resultado = calcular_cubo(9)

print(resultado)
# Out:
# 729

# %%
# Ejercicio 22: Calcular el producto total de una lista
def producto_total(lista):
    return reduce(lambda x, y: x * y, lista)

# %%
# Ejemplo de uso
numeros = [2, 3, 4, 5]

resultado = producto_total(numeros)

print(resultado)
# Out:
# 120

# %%
# Ejercicio 23: Concatenar palabras de una lista
def concatenar_palabras(lista_palabras):
    return reduce(lambda x, y: x + y, lista_palabras)

# %%
# Ejemplo de uso
palabras = ["Hola", " ", "soy", " ", "Tania"]

resultado = concatenar_palabras(palabras)

print(resultado)
# Out:
# Hola soy Tania

# %%
# Ejercicio 24: Calcular la diferencia total de una lista
def diferencia_total(lista):
    return reduce(lambda x, y: x - y, lista)

# %%
# Ejemplo de uso
numeros = [20, 5, 3]

resultado = diferencia_total(numeros)

print(resultado)
# Out:
# 12

# %%
# Ejercicio 25: Contar caracteres en un texto
def contar_caracteres(texto):
    return len(texto)

# %%
# Ejemplo de uso
resultado = contar_caracteres("Hola mundo")

print(resultado)
# Out:
# 10

# %%
# Ejercicio 26: Calcular el resto de una división
def calcular_resto(numero1, numero2):
    resto = lambda x, y: x % y
    return resto(numero1, numero2)

# %%
# Ejemplo de uso
resultado = calcular_resto(17, 3)

print(resultado)
# Out:
# 2

# %%
# Ejercicio 27: Calcular el promedio de una lista de números
def calcular_promedio(lista):
    return sum(lista) / len(lista)

# %%
# Ejemplo de uso
numeros = [10, 20, 30, 40]

resultado = calcular_promedio(numeros)

print(resultado)
# Out:
# 25.0

# %%
# Ejercicio 28: Encontrar el primer elemento duplicado en una lista
def primer_duplicado(lista):
    vistos = set()

    for elemento in lista:
        if elemento in vistos:
            return elemento

        vistos.add(elemento)

    return None

# %%
# Ejemplo de uso
numeros = [1, 3, 5, 2, 3, 8, 5]

resultado = primer_duplicado(numeros)

print(resultado)
# Out:
# 3

# %%
# Ejercicio 29: Enmascarar datos sensibles
def enmascarar_dato(valor):
    texto = str(valor)

    return "#" * (len(texto) - 4) + texto[-4:]

# %%
# Ejemplo de uso
resultado = enmascarar_dato(123456789)

print(resultado)
# Out:
# #####6789

# %%
# Ejercicio 30: Verificar si dos palabras son anagramas
def es_anagrama(palabra1, palabra2):
    return sorted(palabra1.lower()) == sorted(palabra2.lower())

# %%
# Ejemplo de uso
resultado = es_anagrama("roma", "amor")

print(resultado)
# Out:
# True

# %%
# Ejercicio 31: Buscar un nombre en una lista de nombres
def buscar_nombre():
    nombres = input("Introduce varios nombres separados por comas: ").split(",")

    nombre_buscar = input("Introduce el nombre que deseas buscar: ")

    if nombre_buscar in nombres:
        print(f"El nombre '{nombre_buscar}' fue encontrado.")
    else:
        raise ValueError(f"El nombre '{nombre_buscar}' no fue encontrado.")


try:
    buscar_nombre()

except ValueError as error:
    print(error)
# Out:
# El nombre 'maria' fue encontrado.

# %%
# Ejercicio 32: Buscar un nombre completo en una lista de empleados
def buscar_empleado(nombre_completo, empleados):
    nombre_completo = nombre_completo.strip().lower()

    for empleado in empleados:
        if empleado["nombre"].strip().lower() == nombre_completo:
            return empleado["puesto"]

    return "La persona no trabaja aquí."

# %%
# Ejemplo de uso
empleados = [
    {"nombre": "Jonnthan Garcia", "puesto": "Analista de Datos"},
    {"nombre": "Lucero Castro", "puesto": "Desarrollador"},
    {"nombre": "Tania Moreira", "puesto": "Diseñadora"}
]

resultado = buscar_empleado("Lucero castro", empleados)

print(resultado)
# Out:
# Desarrollador

# %%
# Ejercicio 33: Sumar dos listas elemento a elemento
def sumar_listas(lista1, lista2):
    return list(map(lambda x, y: x + y, lista1, lista2))

# %%
# Ejemplo de uso
lista1 = [1, 2, 3]
lista2 = [4, 5, 6]

resultado = sumar_listas(lista1, lista2)

print(resultado)
# Out:
# [5, 7, 9]

# %%
# Ejercicio 34: Crear una clase para representar un árbol  
class Arbol:
    def __init__(self):
        self.tronco = 1
        self.ramas = []

    def crecer_tronco(self):
        self.tronco += 1

    def nueva_rama(self):
        self.ramas.append(1)

    def crecer_ramas(self):
        self.ramas = list(map(lambda rama: rama + 1, self.ramas))

    def quitar_rama(self, posicion):
        self.ramas.pop(posicion)

    def info_arbol(self):
        return f"Longitud del tronco: {self.tronco}. Número de ramas: {len(self.ramas)}. Longitudes de las ramas: {self.ramas}"

# %%
arbol = Arbol()

arbol.crecer_tronco()

arbol.nueva_rama()

arbol.crecer_ramas()

arbol.nueva_rama()
arbol.nueva_rama()

arbol.quitar_rama(2)

print(arbol.info_arbol())
# Out:
# Longitud del tronco: 2. Número de ramas: 2. Longitudes de las ramas: [2, 1]

# %%
# Ejercicio 36: Crear una clase para representar un usuario de banco
class UsuarioBanco:
    def __init__(self, nombre, saldo, cuenta_corriente):
        self.nombre = nombre
        self.saldo = saldo
        self.cuenta_corriente = cuenta_corriente

    def retirar_dinero(self, cantidad):
        if cantidad > self.saldo:
            raise ValueError("No tienes saldo suficiente.")
        else:
            self.saldo -= cantidad

    def transferir_dinero(self, otro_usuario, cantidad):
        if cantidad > otro_usuario.saldo:
            raise ValueError("El otro usuario no tiene saldo suficiente.")
        else:
            otro_usuario.saldo -= cantidad
            self.saldo += cantidad

    def agregar_dinero(self, cantidad):
        self.saldo += cantidad

# %%
try:
    alicia = UsuarioBanco("Alicia", 100, True)
    bob = UsuarioBanco("Bob", 50, True)

    bob.agregar_dinero(20)

    alicia.transferir_dinero(bob, 80)

    alicia.retirar_dinero(50)

    print(alicia.saldo)
    print(bob.saldo)

except ValueError as error:
    print(error)
# Out:
# El otro usuario no tiene saldo suficiente.

# %%
# Ejercicio 37: Crear una función que procese un texto según una opción dada
def contar_palabras(texto):
    palabras = texto.split()
    resultado = {}

    for palabra in palabras:
        if palabra in resultado:
            resultado[palabra] += 1
        else:
            resultado[palabra] = 1

    return resultado

print(contar_palabras("hola mundo hola"))

def reemplazar_palabras(texto, palabra_original, palabra_nueva):
    return texto.replace(palabra_original, palabra_nueva)

print(reemplazar_palabras("hola mundo", "mundo", "Python"))

def eliminar_palabra(texto, palabra):
    return texto.replace(palabra, "")

print(eliminar_palabra("hola mundo", "mundo"))
# Out:
# {'hola': 2, 'mundo': 1}
# hola Python
# hola

# %%
def procesar_texto(texto, opcion, *args):

    if opcion == "contar":
        return contar_palabras(texto)

    elif opcion == "reemplazar":
        return reemplazar_palabras(texto, args[0], args[1])

    elif opcion == "eliminar":
        return eliminar_palabra(texto, args[0])

    else:
        return "Opción no válida"
    
texto = "hola mundo hola python"

print(procesar_texto(texto, "contar"))

print(procesar_texto(texto, "reemplazar", "hola", "adios"))

print(procesar_texto(texto, "eliminar", "python"))
# Out:
# {'hola': 2, 'mundo': 1, 'python': 1}
# adios mundo adios python
# hola mundo hola

# %%
# Ejercicio 38: Determinar si es de día, tarde o noche según la hora
hora = int(input("Introduce la hora (0-23): "))

if hora >= 6 and hora < 12:
    print("Es de día")

elif hora >= 12 and hora < 20:
    print("Es de tarde")

elif hora >= 20 and hora <= 23:
    print("Es de noche")

elif hora >= 0 and hora < 6:
    print("Es de noche")

else:
    print("Hora no válida")
# Out:
# Es de tarde

# %%
# Ejercicio 39: Calificar una nota numérica
calificacion = float(input("Introduce la calificación: "))

if 0 <= calificacion <= 69:
    print("Insuficiente")

elif 70 <= calificacion <= 79:
    print("Bien")

elif 80 <= calificacion <= 89:
    print("Muy bien")

elif 90 <= calificacion <= 100:
    print("Excelente")

else:
    print("Calificación no válida")
# Out:
# Insuficiente

# %%
# Ejercicio 40: Calcular el área de diferentes figuras geométricas
def calcular_area(figura, datos):

    if figura == "rectangulo":
        base, altura = datos
        return base * altura

    elif figura == "circulo":
        radio = datos[0]
        return math.pi * radio ** 2

    elif figura == "triangulo":
        base, altura = datos
        return (base * altura) / 2

    else:
        return "Figura no válida"

# %%
# Ejemplo de uso
print(calcular_area("rectangulo", (5, 4)))
print(calcular_area("circulo", (3,)))
print(calcular_area("triangulo", (10, 5)))
# Out:
# 20
# 28.274333882308138
# 25.0

# %%
# Ejercicio 41: Calcular el precio final de un artículo con descuento
precio = float(input("Introduce el precio del artículo: "))

cupon = input("¿Tienes un cupón de descuento? (si/no): ")

if cupon.lower() == "si":

    descuento = float(input("Introduce el valor del cupón: "))

    if descuento > 0:

        precio_final = precio - descuento

        if precio_final < 0:
            precio_final = 0

        print("El precio final es:", precio_final)

    else:
        print("El descuento no es válido")

else:
    print("El precio final es:", precio)
# Out:
# El precio final es: 36.0
